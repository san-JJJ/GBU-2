# %% [markdown]
# <a href="https://colab.research.google.com/github/san-JJJ/GBU-2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("sanjay")
print("hnn")
# Out:
# sanjay
# hnn

# %%
print("Vanakkam da Colab-la!")


a = 10
b = 20
sum_val = a + b
print("Addition:", sum_val)


numbers = [1, 2, 3, 4, 5]
for num in numbers:
    print("Number:", num)


def greet(name):
    return f"Hello, {name}! Welcome to Data Analytics."

print(greet("Sanjay"))


import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5,1]
y = [10, 25, 100, 30, 20,3]

plt.plot(x, y, marker='o')
plt.title("Simple Line Chart")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()
# Out:
# Vanakkam da Colab-la!
# Addition: 30
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Hello, Sanjay! Welcome to Data Analytics.

# %%
# Data Analysis
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
import sklearn

# File Handling
import csv
import json
import os
import datetime

# Math & Stats
import math
import statistics

# Display Output
from IPython.display import display

# Check versions (optional)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", plt.matplotlib.__version__)
print("seaborn:", sns.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# pandas: 2.2.2
# numpy: 2.0.2
# matplotlib: 3.10.0
# seaborn: 0.13.2
# sklearn: 1.6.1

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ff4136f-ac8e-4bf8-b9a5-3eaf68be53d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ff4136f-ac8e-4bf8-b9a5-3eaf68be53d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# File name example: data.csv
df = pd.read_csv('Student_Marks_Data.csv')  # Replace with your actual file name
df.head()
# Out:
#    Student ID     Name  Subject  Marks  Max Marks Result  Percentage
# 0         101     ravi    maths     88        100   Pass          88
# 1         101    meena    tamil     45        100   Fail          45
# 2         103  karthik  english     60        100   Pass          60
# 3         104    priya     aura     38        100   Fail          38

# %%
import matplotlib.pyplot as plt

# Example: Plot Age vs Salary (if columns available)
plt.plot(df['Name'], df['Marks'], marker='o')
plt.title("Name vs Marks")
plt.xlabel("Name")
plt.ylabel("Marks")
plt.grid(True)
plt.show()
